# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)

display(HTML("<style>.container { width:100% !important; }</style>")) # Hacer mas anchas las celdas
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Cargar archivos

# %%
df_candidate = pd.read_csv(os.path.abspath("df_[candidate]_small.csv"))
df_test_small = pd.read_csv(os.path.abspath("df_[test]_small.csv"))
products_tabla = pd.read_csv(os.path.abspath("producto_tabla.csv"))
town = pd.read_csv(os.path.abspath("town_state_small.csv"))

# %% [markdown]
# ## Ver informacion de archivos

# %% [markdown]
# ### Tabla df_[candidate]_small

# %%
print(df_candidate.info())
print("-"*20)
print(df_candidate.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7974418 entries, 0 to 7974417
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Semana             int64
#  1   Agencia_ID         int64
#  2   Canal_ID           int64
#  3   Ruta_SAK           int64
#  4   Cliente_ID         int64
#  5   Producto_ID        int64
#  6   Venta_uni_hoy      int64
#  7   Venta_hoy          float64
#  8   Dev_uni_proxima    int64
#  9   Dev_proxima        float64
#  10  Demanda_uni_equil  int64
# dtypes: float64(2), int64(9)
# memory usage: 669.2 MB
# None
# --------------------
# Index(['Semana', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID', 'Venta_uni_hoy', 'Venta_hoy', 'Dev_uni_proxima',
#        'Dev_proxima', 'Demanda_uni_equil'],
#       dtype='object')

# %%
df_candidate.head(5)
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
# 1       3        1110         7      3301       15766         1216
# 2       3        1110         7      3301       15766         1238
# 3       3        1110         7      3301       15766         1240
# 4       3        1110         7      3301       15766         1242
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  Demanda_uni_equil
# 0              3      25.14                0          0.0                  3
# 1              4      33.52                0          0.0                  4
# 2              4      39.32                0          0.0                  4
# 3              4      33.52                0          0.0                  4
# 4              3      22.92                0          0.0                  3

# %%
plt.figure(figsize=(22,12))
corr = df_candidate.corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(20, 220, n=200), square=True, annot=True)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.savefig('correlation.png')
plt.show()

# %%
df_candidate[['Venta_uni_hoy','Venta_hoy','Dev_uni_proxima','Dev_proxima','Demanda_uni_equil']].describe()
# Out:
#        Venta_uni_hoy     Venta_hoy  Dev_uni_proxima   Dev_proxima  \
# count   7.974418e+06  7.974418e+06     7.974418e+06  7.974418e+06
# mean    7.534587e+00  8.140738e+01     1.044087e-01  1.209538e+00
# std     2.206313e+01  5.859644e+02     3.211733e+00  2.832457e+01
# min     0.000000e+00  0.000000e+00     0.000000e+00  0.000000e+00
# 25%     2.000000e+00  1.886000e+01     0.000000e+00  0.000000e+00
# 50%     4.000000e+00  3.459000e+01     0.000000e+00  0.000000e+00
# 75%     7.000000e+00  6.540000e+01     0.000000e+00  0.000000e+00
# max     4.800000e+03  6.473600e+05     3.360000e+03  4.950000e+04
#
#        Demanda_uni_equil
# count       7.974418e+06
# mean        7.460012e+00
# std         2.190748e+01
# min         0.000000e+00
# 25%         2.000000e+00
# 50%         4.000000e+00
# 75%         7.000000e+00
# max         4.732000e+03

# %%
# fig, (ax_S3, ax_S4, ax_S5, ax_S6, ax_S7, ax_S8) = plt.subplots(1, 1)
# fig, ([ax_S3, ax_S4, ax_S5], [ax_S6, ax_S7, ax_S8] ) = plt.subplots(3, 2)
# fig, ([ax_S3, ax_S4], [ax_S5, ax_S6]) = plt.subplots(2, 2)

# fig.suptitle("Venta_uni_hoy vs resto de variables", fontsize=20)
# fig.set_size_inches(20, 12)
# fig.subplots_adjust(wspace=.25, left=0.035, right=.985, top=.925, bottom=.1)


# ax_S3.set_title("Venta_uni_hoy vs Venta_hoy")
# ax_S3.set_xlabel(xlabel='Venta_uni_hoy',fontsize=15)
# ax_S3.set_ylabel(ylabel='Venta_hoy', fontsize=15)
# sns.scatterplot(data=vals, ax=ax_S3, x='Venta_uni_hoy', y='Venta_hoy')

# ax_S4.set_title("Venta_uni_hoy vs Dev_uni_proxima")
# ax_S4.set_xlabel(xlabel='Venta_uni_hoy',fontsize=15)
# ax_S4.set_ylabel(ylabel='Dev_uni_proxima', fontsize=15)
# sns.scatterplot(data=vals, ax=ax_S4, x='Venta_uni_hoy', y='Dev_uni_proxima')

# ax_S5.set_title("Venta_uni_hoy vs Dev_proxima")
# ax_S5.set_xlabel(xlabel='Venta_uni_hoy',fontsize=15)
# ax_S5.set_ylabel(ylabel='Dev_proxima', fontsize=15)
# sns.scatterplot(data=vals, ax=ax_S5, x='Venta_uni_hoy', y='Dev_proxima')

# ax_S6.set_title("Venta_uni_hoy vs Demanda_uni_equil")
# ax_S6.set_xlabel(xlabel='Venta_uni_hoy',fontsize=15)
# ax_S6.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
# sns.scatterplot(data=vals, ax=ax_S6, x='Venta_uni_hoy', y='Demanda_uni_equil')

# ax_S7.set_title("Semana 7")
# ax_S7.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
# ax_S7.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
# sns.scatterplot(data=Semana_7, ax=ax_S7, x='Ruta_SAK', y='Demanda_uni_equil')

# ax_S8.set_title("Semana 8")
# ax_S8.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
# ax_S8.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
# sns.scatterplot(data=Semana_8, ax=ax_S8, x='Ruta_SAK', y='Demanda_uni_equil')


plt.show()

# %%
plt.scatter(df_candidate['Venta_uni_hoy'], df_candidate['Venta_uni_hoy'])
plt.title("Venta_uni_hoy vs Venta_uni_hoy")
plt.xlabel("Venta_uni_hoy")
plt.ylabel("Venta_uni_hoy")
plt.savefig('Venta_uni_hoy vs Venta_uni_hoy.png')
plt.show()

# %%
plt.scatter(df_candidate['Venta_uni_hoy'], df_candidate['Venta_hoy'])
plt.title("Venta_uni_hoy vs Venta_uni_hoy")
plt.xlabel("Venta_uni_hoy")
plt.ylabel("Venta_hoy")
plt.savefig('Venta_uni_hoy vs Venta_hoy.png')
plt.show()

# %%
# df_candidate.info()
plt.scatter(df_candidate['Venta_uni_hoy'], df_candidate['Dev_uni_proxima'])
plt.title("Venta_uni_hoy vs Dev_uni_proxima")
plt.xlabel("Venta_uni_hoy")
plt.ylabel("Dev_uni_proxima")
plt.savefig('Venta_uni_hoy vs Dev_uni_proxima.png')
plt.show()

# %%
plt.scatter(df_candidate['Venta_uni_hoy'], df_candidate['Dev_proxima'])
plt.title("Venta_uni_hoy vs Dev_proxima")
plt.xlabel("Venta_uni_hoy")
plt.ylabel("Dev_proxima")
plt.savefig('Venta_uni_hoy vs Dev_proxima.png')
plt.show()

# %%
plt.scatter(df_candidate['Venta_uni_hoy'], df_candidate['Demanda_uni_equil'])
plt.title("Venta_uni_hoy vs Demanda_uni_equil")
plt.xlabel("Venta_uni_hoy")
plt.ylabel("Demanda_uni_equil")
plt.savefig('Venta_uni_hoy vs Demanda_uni_equil.png')
plt.show()

# %%
analysis_stats_candidate = df_candidate[['Venta_uni_hoy','Venta_hoy','Dev_uni_proxima','Dev_proxima','Demanda_uni_equil']].describe().apply(lambda x: x.apply('{0:.4f}'.format))

# %%
analysis_stats_candidate
# Out:
#       Venta_uni_hoy     Venta_hoy Dev_uni_proxima   Dev_proxima  \
# count  7974418.0000  7974418.0000    7974418.0000  7974418.0000
# mean         7.5346       81.4074          0.1044        1.2095
# std         22.0631      585.9644          3.2117       28.3246
# min          0.0000        0.0000          0.0000        0.0000
# 25%          2.0000       18.8600          0.0000        0.0000
# 50%          4.0000       34.5900          0.0000        0.0000
# 75%          7.0000       65.4000          0.0000        0.0000
# max       4800.0000   647360.0000       3360.0000    49500.0000
#
#       Demanda_uni_equil
# count      7974418.0000
# mean             7.4600
# std             21.9075
# min              0.0000
# 25%              2.0000
# 50%              4.0000
# 75%              7.0000
# max           4732.0000

# %%
vals = df_candidate[['Venta_uni_hoy','Venta_hoy','Dev_uni_proxima','Dev_proxima','Demanda_uni_equil']]

# %%
media = vals.mean()
mediana = vals.median()
miin = vals.min()
maax = vals.max()
moda = vals.mode().max()
vari = vals.var()
desv = vals.std()

description = pd.DataFrame(np.array([media, mediana, miin, maax, moda, vari,desv]),
                          columns=[vals.keys()],
                          index=['Media','Mediana','Minimo','Maximo','Moda', 'Varianza','Std'])
description
# Out:
#          Venta_uni_hoy      Venta_hoy Dev_uni_proxima   Dev_proxima  \
# Media         7.534587      81.407380        0.104409      1.209538
# Mediana       4.000000      34.590000        0.000000      0.000000
# Minimo        0.000000       0.000000        0.000000      0.000000
# Maximo     4800.000000  647360.000000     3360.000000  49500.000000
# Moda          2.000000      16.760000        0.000000      0.000000
# Varianza    486.781687  343354.322487       10.315230    802.281446
# Std          22.063130     585.964438        3.211733     28.324573
#
#          Demanda_uni_equil
# Media             7.460012
# Mediana           4.000000
# Minimo            0.000000
# Maximo         4732.000000
# Moda              2.000000
# Varianza        479.937775
# Std              21.907482

# %% [markdown]
# ### Tabla df_[test]_small

# %%
print(df_test_small.info())
print("-"*20)
print(df_test_small.columns)
# df_test_small.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337913 entries, 0 to 1337912
# Data columns (total 6 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Semana       1337913 non-null  int64
#  1   Agencia_ID   1337913 non-null  int64
#  2   Canal_ID     1337913 non-null  int64
#  3   Ruta_SAK     1337913 non-null  int64
#  4   Cliente_ID   1337913 non-null  int64
#  5   Producto_ID  1337913 non-null  int64
# dtypes: int64(6)
# memory usage: 61.2 MB
# None
# --------------------
# Index(['Semana', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID'],
#       dtype='object')

# %%
df_test_small.head(5)
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID
# 0       9        1110         7      3301       15766         1212
# 1       9        1110         7      3301       15766         1238
# 2       9        1110         7      3301       15766         1240
# 3       9        1110         7      3301       15766         1242
# 4       9        1110         7      3301       15766         1250

# %% [markdown]
# ### Tabla producto_tabla

# %%
print(products_tabla.info())
print("-"*20)
print(products_tabla.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2592 entries, 0 to 2591
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Producto_ID     2592 non-null   int64
#  1   NombreProducto  2592 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 40.6+ KB
# None
# --------------------
# Index(['Producto_ID', 'NombreProducto'], dtype='object')

# %%
products_tabla.head(5)
# Out:
#    Producto_ID                          NombreProducto
# 0            0                       NO IDENTIFICADO 0
# 1            9               Capuccino Moka 750g NES 9
# 2           41  Bimbollos Ext sAjonjoli 6p 480g BIM 41
# 3           53          Burritos Sincro 170g CU LON 53
# 4           72     Div Tira Mini Doradita 4p 45g TR 72

# %% [markdown]
# ### Tabla town_state_small

# %%
print(town.info())
print("-"*20)
print(town.columns)
# town.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Agencia_ID  41 non-null     int64
#  1   Town        41 non-null     object
#  2   State       41 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.1+ KB
# None
# --------------------
# Index(['Agencia_ID', 'Town', 'State'], dtype='object')

# %%
town.head(5)
# Out:
#    Agencia_ID                   Town             State
# 0        1110     2008 AG. LAGO FILT      MÉXICO, D.F.
# 1        1111  2002 AG. AZCAPOTZALCO      MÉXICO, D.F.
# 2        1112    2004 AG. CUAUTITLAN  ESTADO DE MÉXICO
# 3        1113     2008 AG. LAGO FILT      MÉXICO, D.F.
# 4        1114   2029 AG.IZTAPALAPA 2      MÉXICO, D.F.

# %% [markdown]
# ## Separamos la tabla, en subconjuntos de semana, es decir obtenemos toda la informacion perteneciente a la semana 1, 2, 3, ..., 8
# ### **NOTA: No hay registros para la semana 1 y 2**

# %%
Semana_3 = df_candidate[df_candidate['Semana']==3]
Semana_4 = df_candidate[df_candidate['Semana']==4]
Semana_5 = df_candidate[df_candidate['Semana']==5]
Semana_6 = df_candidate[df_candidate['Semana']==6]
Semana_7 = df_candidate[df_candidate['Semana']==7]
Semana_8 = df_candidate[df_candidate['Semana']==8]
Semana_8.head(5)
# df_candidate[df_candidate['Semana']==4].count()  # Para conocer cuantos registros existen en esa semana
# Out:
#          Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 6633981       8        1110         7      3301       15766         1212
# 6633982       8        1110         7      3301       15766         1216
# 6633983       8        1110         7      3301       15766         1220
# 6633984       8        1110         7      3301       15766         1238
# 6633985       8        1110         7      3301       15766         1240
#
#          Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  \
# 6633981              4      33.52                0          0.0
# 6633982              5      41.90                0          0.0
# 6633983              1       7.64                0          0.0
# 6633984              3      29.49                0          0.0
# 6633985              2      16.76                0          0.0
#
#          Demanda_uni_equil
# 6633981                  4
# 6633982                  5
# 6633983                  1
# ...

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# ### Buscamos missing values, valores nulos, nan en los dataset de las semanas

# %%
# Para buscar missing values
print("Semana 3")
print(Semana_3.isnull().values.any())
# print(Semana_3.isnull().sum())
print("Semana 4")
print(Semana_4.isnull().values.any())
# print(Semana_4.isnull().sum())
print("Semana 5")
print(Semana_5.isnull().values.any())
# print(Semana_5.isnull().sum())
print("Semana 6")
print(Semana_6.isnull().values.any())
# print(Semana_6.isnull().sum())
print("Semana 7")
print(Semana_7.isnull().values.any())
# print(Semana_7.isnull().sum())
print("Semana 8")
print(Semana_8.isnull().values.any())
# print(Semana_8.isnull().sum())
# Out:
# Semana 3
# False
# Semana 4
# False
# Semana 5
# False
# Semana 6
# False
# Semana 7
# False
# Semana 8
# False

# %% [markdown]
# ### Busqueda de productos repetidos

# %%
products_tabla.duplicated(keep=False).sum()
# Out:
# 0

# %%
# Extra
CPA = df_candidate[['Cliente_ID','Producto_ID','Agencia_ID']]
CPA.tail(5)

unicos_Prod = df_candidate['Producto_ID'].unique()
unicos_Prod
len(unicos_Prod)
# Out:
# 710

# %% [markdown]
# ## Analisis de los datos

# %% [markdown]
# ### Comportamiento de Ruta_SAK — Route ID (Several routes = Sales Depot) por semana

# %%
# plt.scatter(Semana_3['Ruta_SAK'], Semana_3['Demanda_uni_equil'])
# plt.title("Semana 3")
# plt.xlabel('Ruta_SAK')
# plt.ylabel('Demanda_uni_equil')
# plt.show()

plt.figure(figsize=(22,12))
plt.scatter(df_candidate['Ruta_SAK'], df_candidate['Demanda_uni_equil'])
plt.title("Ruta_SAK vs Demanda entre las semanas 3 a 8")
plt.xlabel('Ruta_SAK')
plt.ylabel('Demanda_uni_equil\n Adjusted Demand')

plt.savefig('Ruta_SAK vs Demanda entre las semanas 3 a 8.png')

plt.show()

# %%
# fig, (ax_S3, ax_S4, ax_S5, ax_S6, ax_S7, ax_S8) = plt.subplots(1, 1)
fig, ([ax_S3, ax_S4, ax_S5], [ax_S6, ax_S7, ax_S8] ) = plt.subplots(2, 3)

fig.suptitle("Ruta_SAK vs Demanda por Semana", fontsize=20)
fig.set_size_inches(20, 12)
fig.subplots_adjust(wspace=.25, left=0.035, right=.985, top=.925, bottom=.1)


ax_S3.set_title("Semana 3")
ax_S3.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
ax_S3.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_3, ax=ax_S3, x='Ruta_SAK', y='Demanda_uni_equil')

ax_S4.set_title("Semana 4")
ax_S4.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
ax_S4.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_4, ax=ax_S4, x='Ruta_SAK', y='Demanda_uni_equil')

ax_S5.set_title("Semana 5")
ax_S5.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
ax_S5.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_5, ax=ax_S5, x='Ruta_SAK', y='Demanda_uni_equil')

ax_S6.set_title("Semana 6")
ax_S6.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
ax_S6.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_6, ax=ax_S6, x='Ruta_SAK', y='Demanda_uni_equil')

ax_S7.set_title("Semana 7")
ax_S7.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
ax_S7.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_7, ax=ax_S7, x='Ruta_SAK', y='Demanda_uni_equil')

ax_S8.set_title("Semana 8")
ax_S8.set_xlabel(xlabel='Ruta_SAK',fontsize=15)
ax_S8.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_8, ax=ax_S8, x='Ruta_SAK', y='Demanda_uni_equil')

plt.savefig('Ruta_SAK vs Demanda por Semana.png')

plt.show()

# %% [markdown]
# ### Comportamiento de Cliente_ID — Client ID por semana

# %%
plt.figure(figsize=(22,12))
plt.scatter(df_candidate['Cliente_ID'], df_candidate['Demanda_uni_equil'])
plt.title("Cliente_ID vs Demanda entre las semanas 3 a 8")
plt.xlabel('Cliente_ID')
plt.ticklabel_format(style="plain")
plt.ylabel('Demanda_uni_equil\n Adjusted Demand')
plt.savefig('Cliente_ID vs Demanda entre las semanas 3 a 8.png')
plt.show()

# %%
a = df_candidate[df_candidate['Cliente_ID']==99999999]
#a.count()  #- > 7974418
a.head(5)
# a['Demanda_uni_equil'].sum()
unicos = a['Demanda_uni_equil'].unique()
unicos.max()
# Out:
# 20

# %%
fig, ([ax_S3, ax_S4, ax_S5], [ax_S6, ax_S7, ax_S8] ) = plt.subplots(2, 3)

fig.suptitle("Cliente_ID vs Demanda por Semana", fontsize=20)
fig.set_size_inches(20, 12)
fig.subplots_adjust(wspace=.25, left=0.035, right=.985, top=.925, bottom=.1)


ax_S3.set_title("Semana 3")
ax_S3.set_xlabel(xlabel='Cliente_ID',fontsize=15)
ax_S3.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_3, ax=ax_S3, x='Cliente_ID', y='Demanda_uni_equil')

ax_S4.set_title("Semana 4")
ax_S4.set_xlabel(xlabel='Cliente_ID',fontsize=15)
ax_S4.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_4, ax=ax_S4, x='Cliente_ID', y='Demanda_uni_equil')

ax_S5.set_title("Semana 5")
ax_S5.set_xlabel(xlabel='Cliente_ID',fontsize=15)
ax_S5.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_5, ax=ax_S5, x='Cliente_ID', y='Demanda_uni_equil')

ax_S6.set_title("Semana 6")
ax_S6.set_xlabel(xlabel='Cliente_ID',fontsize=15)
ax_S6.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_6, ax=ax_S6, x='Cliente_ID', y='Demanda_uni_equil')

ax_S7.set_title("Semana 7")
ax_S7.set_xlabel(xlabel='Cliente_ID',fontsize=15)
ax_S7.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_7, ax=ax_S7, x='Cliente_ID', y='Demanda_uni_equil')

ax_S8.set_title("Semana 8")
ax_S8.set_xlabel(xlabel='Cliente_ID',fontsize=15)
ax_S8.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_8, ax=ax_S8, x='Cliente_ID', y='Demanda_uni_equil')

plt.savefig('Cliente_ID vs Demanda por Semana.png')
plt.show()

# %%
c = df_candidate[(df_candidate["Semana"]==8) & (df_candidate['Cliente_ID']==Semana_8['Cliente_ID'].min())]
c
# Out:
#          Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 6870460       8        1117         1      1049        3967         1109
# 6870461       8        1117         1      1049        3967         1146
# 6870462       8        1117         1      1049        3967         1150
# 6870463       8        1117         1      1049        3967         1160
# 6870464       8        1117         1      1049        3967         1182
# 6870465       8        1117         1      1049        3967         2233
# 6870466       8        1117         1      1049        3967         2665
# 6870467       8        1117         1      1049        3967         3144
# 6870468       8        1117         1      1049        3967         3631
# 6870469       8        1117         1      1049        3967         4767
# 6903615       8        1117         1      1449        3967          972
# 6903616       8        1117         1      1449        3967         1064
# ...

# %%
c = Semana_8['Cliente_ID']
c.head()
# Out:
# 6633981    15766
# 6633982    15766
# 6633983    15766
# 6633984    15766
# 6633985    15766
# Name: Cliente_ID, dtype: int64

# %%
len(c)
# Out:
# 1340437

# %% [markdown]
# ### Comportamiento de Producto_ID — Product ID, por semana

# %%
plt.figure(figsize=(22,12))
plt.scatter(df_candidate['Producto_ID'], df_candidate['Demanda_uni_equil'])
plt.title("Producto_ID vs Demanda entre las semanas 3 a 8")
plt.xlabel('Producto_ID')
plt.ticklabel_format(style="plain")
plt.ylabel('Demanda_uni_equil\n Adjusted Demand')
plt.savefig('Producto_ID vs Demanda entre las semanas 3 a 8.png')
plt.show()

# %%
fig, ([ax_S3, ax_S4, ax_S5], [ax_S6, ax_S7, ax_S8] ) = plt.subplots(2, 3)

fig.suptitle("Producto_ID vs Demanda por Semana", fontsize=20)
fig.set_size_inches(20, 12)
fig.subplots_adjust(wspace=.25, left=0.035, right=.985, top=.925, bottom=.1)


ax_S3.set_title("Semana 3")
ax_S3.set_xlabel(xlabel='Producto_ID',fontsize=15)
ax_S3.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_3, ax=ax_S3, x='Producto_ID', y='Demanda_uni_equil')

ax_S4.set_title("Semana 4")
ax_S4.set_xlabel(xlabel='Producto_ID',fontsize=15)
ax_S4.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_4, ax=ax_S4, x='Producto_ID', y='Demanda_uni_equil')

ax_S5.set_title("Semana 5")
ax_S5.set_xlabel(xlabel='Producto_ID',fontsize=15)
ax_S5.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_5, ax=ax_S5, x='Producto_ID', y='Demanda_uni_equil')

ax_S6.set_title("Semana 6")
ax_S6.set_xlabel(xlabel='Producto_ID',fontsize=15)
ax_S6.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_6, ax=ax_S6, x='Producto_ID', y='Demanda_uni_equil')

ax_S7.set_title("Semana 7")
ax_S7.set_xlabel(xlabel='Producto_ID',fontsize=15)
ax_S7.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_7, ax=ax_S7, x='Producto_ID', y='Demanda_uni_equil')

ax_S8.set_title("Semana 8")
ax_S8.set_xlabel(xlabel='Producto_ID',fontsize=15)
ax_S8.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_8, ax=ax_S8, x='Producto_ID', y='Demanda_uni_equil')

plt.savefig('Producto_ID vs Demanda por Semana.png')

plt.show()

# %% [markdown]
# ### Comportamientode los datos de Agencia_ID — Sales Depot ID, por semana

# %%
plt.figure(figsize=(22,12))
plt.scatter(df_candidate['Agencia_ID'], df_candidate['Demanda_uni_equil'])
plt.title("Agencia_ID vs Demanda entre las semanas 3 a 8")
plt.xlabel('Agencia_ID')
plt.ticklabel_format(style="plain")
plt.ylabel('Demanda_uni_equil\n Adjusted Demand')
plt.savefig('Agencia_ID vs Demanda entre las semanas 3 a 8.png')
plt.show()

# %%
fig, ([ax_S3, ax_S4, ax_S5], [ax_S6, ax_S7, ax_S8] ) = plt.subplots(2, 3)

fig.suptitle("Agencia_ID vs Demanda por Semana", fontsize=20)
fig.set_size_inches(20, 12)
fig.subplots_adjust(wspace=.25, left=0.035, right=.985, top=.925, bottom=.1)


ax_S3.set_title("Semana 3")
ax_S3.set_xlabel(xlabel='Agencia_ID',fontsize=15)
ax_S3.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_3, ax=ax_S3, x='Agencia_ID', y='Demanda_uni_equil')

ax_S4.set_title("Semana 4")
ax_S4.set_xlabel(xlabel='Agencia_ID',fontsize=15)
ax_S4.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_4, ax=ax_S4, x='Agencia_ID', y='Demanda_uni_equil')

ax_S5.set_title("Semana 5")
ax_S5.set_xlabel(xlabel='Agencia_ID',fontsize=15)
ax_S5.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_5, ax=ax_S5, x='Agencia_ID', y='Demanda_uni_equil')

ax_S6.set_title("Semana 6")
ax_S6.set_xlabel(xlabel='Agencia_ID',fontsize=15)
ax_S6.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_6, ax=ax_S6, x='Agencia_ID', y='Demanda_uni_equil')

ax_S7.set_title("Semana 7")
ax_S7.set_xlabel(xlabel='Agencia_ID',fontsize=15)
ax_S7.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_7, ax=ax_S7, x='Agencia_ID', y='Demanda_uni_equil')

ax_S8.set_title("Semana 8")
ax_S8.set_xlabel(xlabel='Agencia_ID',fontsize=15)
ax_S8.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_8, ax=ax_S8, x='Agencia_ID', y='Demanda_uni_equil')

plt.savefig('Agencia_ID vs Demanda por Semana.png')
plt.show()

# %% [markdown]
# ### Comportamientode los datos de Canal_ID — Sales Channel ID, por semana

# %%
plt.figure(figsize=(22,12))
plt.scatter(df_candidate['Canal_ID'], df_candidate['Demanda_uni_equil'])
plt.title("Canal_ID vs Demanda entre las semanas 3 a 8")
plt.xlabel('Canal_ID')
plt.ticklabel_format(style="plain")
plt.ylabel('Demanda_uni_equil\n Adjusted Demand')
plt.savefig('Canal_ID vs Demanda entre las semanas 3 a 8.png')
plt.show()

# %%
fig, ([ax_S3, ax_S4, ax_S5], [ax_S6, ax_S7, ax_S8] ) = plt.subplots(2, 3)

fig.suptitle("Canal_ID vs Demanda por Semana", fontsize=20)
fig.set_size_inches(20, 12)
fig.subplots_adjust(wspace=.25, left=0.035, right=.985, top=.925, bottom=.1)


ax_S3.set_title("Semana 3")
ax_S3.set_xlabel(xlabel='Canal_ID',fontsize=15)
ax_S3.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_3, ax=ax_S3, x='Canal_ID', y='Demanda_uni_equil')

ax_S4.set_title("Semana 4")
ax_S4.set_xlabel(xlabel='Canal_ID',fontsize=15)
ax_S4.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_4, ax=ax_S4, x='Canal_ID', y='Demanda_uni_equil')

ax_S5.set_title("Semana 5")
ax_S5.set_xlabel(xlabel='Canal_ID',fontsize=15)
ax_S5.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_5, ax=ax_S5, x='Canal_ID', y='Demanda_uni_equil')

ax_S6.set_title("Semana 6")
ax_S6.set_xlabel(xlabel='Canal_ID',fontsize=15)
ax_S6.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_6, ax=ax_S6, x='Canal_ID', y='Demanda_uni_equil')

ax_S7.set_title("Semana 7")
ax_S7.set_xlabel(xlabel='Canal_ID',fontsize=15)
ax_S7.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_7, ax=ax_S7, x='Canal_ID', y='Demanda_uni_equil')

ax_S8.set_title("Semana 8")
ax_S8.set_xlabel(xlabel='Canal_ID',fontsize=15)
ax_S8.set_ylabel(ylabel='Demanda_uni_equil', fontsize=15)
sns.scatterplot(data=Semana_8, ax=ax_S8, x='Canal_ID', y='Demanda_uni_equil')

plt.savefig('Canal_ID vs Demanda por Semana.png')
plt.show()

# %%
# temporal = df_candidate.copy()
# from scipy.stats import norm,boxcox
# temporal['normDemand'] = boxcox(temporal['Demanda_uni_equil']+1)[0]
# temporal.drop(['Canal_ID','Venta_uni_hoy','Venta_hoy','Dev_proxima','Dev_uni_proxima','Demanda_uni_equil'], axis=1, inplace=True)

#  0   Semana             int64  
#  1   Agencia_ID         int64  
#  2   Canal_ID           int64  
#  3   Ruta_SAK           int64  
#  4   Cliente_ID         int64  
#  5   Producto_ID        int64  
#  6   Venta_uni_hoy      int64  
#  7   Venta_hoy          float64
#  8   Dev_uni_proxima    int64  
#  9   Dev_proxima        float64
#  10  Demanda_uni_equil  int64

# %%
# from sklearn.linear_model import LinearRegression
# X_train = temporal[temporal['Semana']!=8].copy()
# y_train = X_train['normDemand']
# X_test = temporal[temporal['Semana']==8].copy()
# y_test = X_test['normDemand']

# %%
# import lightgbm as lgb

# %%
# hyper_params = {
#     'boosting_type': 'gbdt',
#     'objective': 'regression',
#     'metric': ['l2', 'l1'],
#     'n_estimators' : 100
# }

# regressor  = LinearRegression().fit(X_train, y_train)
# print(regressor.intercept_)

# %%
# print(regressor.coef_)

# %%
# y_pred = regressor.predict(X_test)
# df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# df

# %%
# from sklearn import metrics
# print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
